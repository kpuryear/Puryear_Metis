# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
df = pd.DataFrame.from_csv('/Users/kaitlin/ds/metis/metisgh/Puryear_Metis/Project3/NoShows.csv', 
                      header=0, 
                      sep=',', 
                      index_col=0, 
                      parse_dates=True, 
                      encoding=None, 
                      tupleize_cols=None, 
                      infer_datetime_format=False)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls

# %%
# raw data comes in looking like...
df.head()
# Out:
#               AppointmentID Gender          ScheduledDay  \
# PatientId
# 2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#                     AppointmentDay  Age      Neighbourhood  Scholarship  \
# PatientId
# 2.987250e+13  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# 5.589978e+14  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0
# 4.262962e+12  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0
# 8.679512e+11  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0
# 8.841186e+12  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0
#
#               Hipertension  Diabetes  Alcoholism  Handcap  SMS_received  \
# PatientId
# 2.987250e+13             1         0           0        0             0
# ...

# %%
# fix typos in column headings...
df = df.rename(index=str, columns={"SMS_received": "Text_Sent", 
                              "Hipertension": "Hypertension", 
                              "Handcap": "Handicap",
                                  "Neighbourhood": "neighborhood"})
df.head()
# Out:
#                    AppointmentID Gender          ScheduledDay  \
# PatientId
# 29872499824296.0         5642903      F  2016-04-29T18:38:08Z
# 558997776694438.0        5642503      M  2016-04-29T16:08:27Z
# 4262962299951.0          5642549      F  2016-04-29T16:19:04Z
# 867951213174.0           5642828      F  2016-04-29T17:29:31Z
# 8841186448183.0          5642494      F  2016-04-29T16:07:23Z
#
#                          AppointmentDay  Age       neighborhood  Scholarship  \
# PatientId
# 29872499824296.0   2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# 558997776694438.0  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0
# 4262962299951.0    2016-04-29T00:00:00Z   62      MATA DA PRAIA            0
# 867951213174.0     2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0
# 8841186448183.0    2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0
#
#                    Hypertension  Diabetes  Alcoholism  Handicap  Text_Sent  \
# PatientId
# ...

# %%
# boolean True or False for response variable..
df["Showed_up"] = (df["No-show"] == "No")

# %%
# Make all values in X booleans!
df["woman"] = (df["Gender"] == 'F')
df["Scholarship"] = (df["Scholarship"] == 1)
df["Hypertension"] = (df["Hypertension"] == 1)
df["Diabetes"] = (df["Diabetes"] == 1)
df["Alcoholism"] = (df["Alcoholism"] == 1)
df["Handicap"] = (df["Handicap"] == 1)
df["Text_Sent"] = (df["Text_Sent"] == 1)

# %%
df.head()
# Out:
#                    AppointmentID Gender          ScheduledDay  \
# PatientId
# 29872499824296.0         5642903      F  2016-04-29T18:38:08Z
# 558997776694438.0        5642503      M  2016-04-29T16:08:27Z
# 4262962299951.0          5642549      F  2016-04-29T16:19:04Z
# 867951213174.0           5642828      F  2016-04-29T17:29:31Z
# 8841186448183.0          5642494      F  2016-04-29T16:07:23Z
#
#                          AppointmentDay  Age       neighborhood  Scholarship  \
# PatientId
# 29872499824296.0   2016-04-29T00:00:00Z   62    JARDIM DA PENHA        False
# 558997776694438.0  2016-04-29T00:00:00Z   56    JARDIM DA PENHA        False
# 4262962299951.0    2016-04-29T00:00:00Z   62      MATA DA PRAIA        False
# 867951213174.0     2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI        False
# 8841186448183.0    2016-04-29T00:00:00Z   56    JARDIM DA PENHA        False
#
#                    Hypertension  Diabetes  Alcoholism  Handicap  Text_Sent  \
# PatientId
# ...

# %%
df["appointment_today"] = [datetime.strptime(x,'%Y-%m-%dT%H:%M:%SZ') for x in df["AppointmentDay"]]
#df['appointment_today'] = [datetime(x) for x in df["appointment_today"]]

df["scheduled_today"] = [datetime.strptime(x,'%Y-%m-%dT%H:%M:%SZ') for x in df["ScheduledDay"]]
#df['scheduled_today'] = [datetime(x) for x in df["scheduled_today"]]

# %%
df["delta"] = [((x-y).days)+1 for x,y in zip(df['appointment_today'], df["scheduled_today"])]

# %%
df.head()
# Out:
#                    AppointmentID Gender          ScheduledDay  \
# PatientId
# 29872499824296.0         5642903      F  2016-04-29T18:38:08Z
# 558997776694438.0        5642503      M  2016-04-29T16:08:27Z
# 4262962299951.0          5642549      F  2016-04-29T16:19:04Z
# 867951213174.0           5642828      F  2016-04-29T17:29:31Z
# 8841186448183.0          5642494      F  2016-04-29T16:07:23Z
#
#                          AppointmentDay  Age       neighborhood  Scholarship  \
# PatientId
# 29872499824296.0   2016-04-29T00:00:00Z   62    JARDIM DA PENHA        False
# 558997776694438.0  2016-04-29T00:00:00Z   56    JARDIM DA PENHA        False
# 4262962299951.0    2016-04-29T00:00:00Z   62      MATA DA PRAIA        False
# 867951213174.0     2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI        False
# 8841186448183.0    2016-04-29T00:00:00Z   56    JARDIM DA PENHA        False
#
#                    Hypertension  Diabetes  Alcoholism  Handicap  Text_Sent  \
# PatientId
# ...

# %%
df = df.drop(['AppointmentDay',
              'appointment_today',
              'scheduled_today',
              'Gender',
              'ScheduledDay', 
              'AppointmentID',
              'No-show'], axis=1)

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#         Age       neighborhood  Scholarship  Hypertension  Diabetes  \
# 0        62    JARDIM DA PENHA        False          True     False
# 1        56    JARDIM DA PENHA        False         False     False
# 2        62      MATA DA PRAIA        False         False     False
# 3         8  PONTAL DE CAMBURI        False         False     False
# 4        56    JARDIM DA PENHA        False          True      True
# 5        76          REPÚBLICA        False          True     False
# 6        23         GOIABEIRAS        False         False     False
# 7        39         GOIABEIRAS        False         False     False
# 8        21         ANDORINHAS        False         False     False
# 9        19          CONQUISTA        False         False     False
# 10       30     NOVA PALESTINA        False         False     False
# 11       29     NOVA PALESTINA        False         False     False
# 12       22     NOVA PALESTINA         True         False     False
# ...

# %%
df2 = pd.DataFrame.dropna(df)

# %%
df2 = df2.drop('neighborhood', axis=1)

# %%
df2.head()
# Out:
#    Age  Scholarship  Hypertension  Diabetes  Alcoholism  Handicap  Text_Sent  \
# 0   62        False          True     False       False     False      False
# 1   56        False         False     False       False     False      False
# 2   62        False         False     False       False     False      False
# 3    8        False         False     False       False     False      False
# 4   56        False          True      True       False     False      False
#
#    Showed_up  woman  delta
# 0       True   True      0
# 1       True  False      0
# 2       True   True      0
# 3       True   True      0
# 4       True   True      0

# %%
df2.to_csv('noshowclean_n.csv', encoding='utf-8', index=True)

# %%
hood_list = list(set(df2.neighborhood))

# %%
df3 = pd.get_dummies(df2.neighborhood)

# %%
for item in hood_list: 
    df3[item] = (df3[item]==1)

# %%
result = pd.concat([df3, df2], axis=1)

# %%
result.head()
# Out:
#    AEROPORTO  ANDORINHAS  ANTÔNIO HONÓRIO  ARIOVALDO FAVALESSA  \
# 0      False       False            False                False
# 1      False       False            False                False
# 2      False       False            False                False
# 3      False       False            False                False
# 4      False       False            False                False
#
#    BARRO VERMELHO  BELA VISTA  BENTO FERREIRA  BOA VISTA  BONFIM  CARATOÍRA  \
# 0           False       False           False      False   False      False
# 1           False       False           False      False   False      False
# 2           False       False           False      False   False      False
# 3           False       False           False      False   False      False
# 4           False       False           False      False   False      False
#
#    ...         neighborhood  Scholarship  Hypertension  Diabetes  Alcoholism  \
# ...

# %%
df5 = result.drop(['neighborhood'], axis=1)

# %%
df5.to_csv('noshowclean.csv', encoding='utf-8', index=False)

# %%
df5.columns
# Out:
# Index(['AEROPORTO', 'ANDORINHAS', 'ANTÔNIO HONÓRIO', 'ARIOVALDO FAVALESSA',
#        'BARRO VERMELHO', 'BELA VISTA', 'BENTO FERREIRA', 'BOA VISTA', 'BONFIM',
#        'CARATOÍRA', 'CENTRO', 'COMDUSA', 'CONQUISTA', 'CONSOLAÇÃO',
#        'CRUZAMENTO', 'DA PENHA', 'DE LOURDES', 'DO CABRAL', 'DO MOSCOSO',
#        'DO QUADRO', 'ENSEADA DO SUÁ', 'ESTRELINHA', 'FONTE GRANDE',
#        'FORTE SÃO JOÃO', 'FRADINHOS', 'GOIABEIRAS', 'GRANDE VITÓRIA',
#        'GURIGICA', 'HORTO', 'ILHA DAS CAIEIRAS', 'ILHA DE SANTA MARIA',
#        'ILHA DO BOI', 'ILHA DO FRADE', 'ILHA DO PRÍNCIPE',
#        'ILHAS OCEÂNICAS DE TRINDADE', 'INHANGUETÁ', 'ITARARÉ', 'JABOUR',
#        'JARDIM CAMBURI', 'JARDIM DA PENHA', 'JESUS DE NAZARETH', 'JOANA D´ARC',
#        'JUCUTUQUARA', 'MARIA ORTIZ', 'MARUÍPE', 'MATA DA PRAIA', 'MONTE BELO',
#        'MORADA DE CAMBURI', 'MÁRIO CYPRESTE', 'NAZARETH', 'NOVA PALESTINA',
#        'PARQUE INDUSTRIAL', 'PARQUE MOSCOSO', 'PIEDADE', 'PONTAL DE CAMBURI',
# ...

# %%
df5.head()
# Out:
#    AEROPORTO  ANDORINHAS  ANTÔNIO HONÓRIO  ARIOVALDO FAVALESSA  \
# 0      False       False            False                False
# 1      False       False            False                False
# 2      False       False            False                False
# 3      False       False            False                False
# 4      False       False            False                False
#
#    BARRO VERMELHO  BELA VISTA  BENTO FERREIRA  BOA VISTA  BONFIM  CARATOÍRA  \
# 0           False       False           False      False   False      False
# 1           False       False           False      False   False      False
# 2           False       False           False      False   False      False
# 3           False       False           False      False   False      False
# 4           False       False           False      False   False      False
#
#    ...    Age  Scholarship  Hypertension  Diabetes  Alcoholism  Handicap  \
# ...
