# %%
import pandas as pd
import numpy as np
from collections import defaultdict
import matplotlib.pyplot as plt
from IPython.display import Image
import seaborn as sns
import csv
import datetime


# %matplotlib inline

# %%
import urllib  # the lib that handles the url stuff
import io
import requests

url = 'https://www2.census.gov/programs-surveys/nychvs/datasets/2014/microdata/uf_14_pers_web_b.txt'
f=requests.get(url).content
df=pd.read_csv(io.StringIO(f.decode('utf-8')))

# %%
url = 'http://web.mta.info/developers/data/nyct/turnstile/turnstile_170513.txt'
f=requests.get(url).content
df1=pd.read_csv(io.StringIO(f.decode('utf-8')))

url = 'http://web.mta.info/developers/data/nyct/turnstile/turnstile_170506.txt'
f=requests.get(url).content
df2=pd.read_csv(io.StringIO(f.decode('utf-8')))

url = 'http://web.mta.info/developers/data/nyct/turnstile/turnstile_170429.txt'
f=requests.get(url).content
df3=pd.read_csv(io.StringIO(f.decode('utf-8')))

url = 'http://web.mta.info/developers/data/nyct/turnstile/turnstile_170422.txt'
f=requests.get(url).content
df4=pd.read_csv(io.StringIO(f.decode('utf-8')))

df = pd.concat([df1, df2, df3, df4])

# %%
df = df.reset_index(drop=True)

# %%
cleandf = df.groupby(['SCP','STATION', 'DATE', 'TIME']).sum()

# %%
cleandf2 = cleandf.groupby(['SCP','STATION','DATE']).agg(lambda x: max(x) - min(x))

# %%
cleandf3 = cleandf2.groupby(['STATION', 'DATE']).sum()

# %%
cleandf3 = cleandf3[cleandf3['ENTRIES']>1000]
cleandf3 = cleandf3[cleandf3['ENTRIES']<100000]

# %%
tot = cleandf3.groupby(['STATION']).sum()

# %%
tot = tot[tot['ENTRIES'] > 1000000]

# %%
tot
# Out:
#                  ENTRIES  \
# STATION
# 14 ST-UNION SQ   2333701
# 47-50 STS ROCK   1211506
# 59 ST COLUMBUS   1527193
# CHAMBERS ST      1220127
# FLUSHING-MAIN    1375806
# JKSN HT-ROOSVLT  1165390
# PATH NEW WTC     1074386
# TIMES SQ-42 ST   1597627
#
#                  EXITS
# STATION
# 14 ST-UNION SQ                                             2182378
# 47-50 STS ROCK                                             1357395
# 59 ST COLUMBUS                                             1338854
# CHAMBERS ST                                                1069199
# FLUSHING-MAIN                                               953108
# JKSN HT-ROOSVLT                                             805222
# PATH NEW WTC                                               1020539
# TIMES SQ-42 ST                                             1740028

# %%
def plotmystation(station) :
    sns.barplot(x = cleandf3.loc[station]['ENTRIES'], y = cleandf3.loc[station]['ENTRIES'].keys())

# %%
plotmystation('TIMES SQ-42 ST')

# %%
plotmystation('14 ST-UNION SQ')

# %%
plotmystation('47-50 STS ROCK')

# %%
plotmystation('59 ST COLUMBUS')

# %%
plotmystation('CHAMBERS ST')

# %%
plotmystation('FLUSHING-MAIN')

# %%
plotmystation('JKSN HT-ROOSVLT')

# %%
plotmystation('PATH NEW WTC')

# %%
plotmystation('TIMES SQ-42 ST')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 25)
pd.set_option('display.precision', 2)

# %%
censusdata = pd.read_csv('uf_14_pers_web_b.txt', header = None)

# %%
censusdata.to_string()
# Out:
        borough.append(person[1])
    return(borough)

# %%
#takes the gender value out of the raw data

def getsex(df):
    sex = []
    for index, row in df.iterrows():
        person = df.iloc[index][0]
        sex.append(person[4])
    return(sex)

# %%
#takes the age value out of the raw data

def getage(df):
    age = []
    for index, row in df.iterrows():
        person = df.iloc[index][0]
        age.append(person[5:7])
    return(age)

# %%
#creates a data frame with the important stuff

cendf = pd.DataFrame({ 'Borough' : getborough(censusdata), \
                    'Sub-Borough' : getsubborough(censusdata), \
                    'Income' : getincome(censusdata), \
                    'Age' : getage(censusdata), \
                    'Sex' : getsex(censusdata)
                    })

# %%
#converts the elements of the data frame to numbers

cendf = cendf.convert_objects(convert_numeric=True)
# Out:
# /Users/gilliangoodman/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#removes all elements of the data frame where the income value = 9999999 which means NA

cendf2 = cendf[cendf['Income'] < 9999999]

# %%
def whatborough(df, borough):
    boroughdf = df[df['Borough'] == borough]
    return(boroughdf)

# %%
Bronx = whatborough(cleandf2, 1)

# %%
Brooklyn = whatborough(cleandf2, 2)

# %%
Manhattan = whatborough(cleandf2, 3)

# %%
Queens = whatborough(cleandf2, 4)

# %%
StatenIsland = whatborough(cleandf2, 5)

# %%
Manhattan.describe()
# Out:
#            Age  Borough    Income      Sex  Sub-Borough
# count  6296.00   6296.0  6.30e+03  6296.00      6296.00
# mean     46.25      3.0  8.75e+04     1.52         5.57
# std      17.91      0.0  1.56e+05     0.50         2.82
# min      15.00      3.0 -8.00e+04     1.00         1.00
# 25%      31.00      3.0  1.76e+04     1.00         3.00
# 50%      43.00      3.0  4.44e+04     2.00         6.00
# 75%      60.00      3.0  9.00e+04     2.00         8.00
# max      85.00      3.0  1.76e+06     2.00        10.00

# %%
def whatsubborough(df, subborough):
    subboroughdf = df[df['Sub-Borough'] == subborough]
    return(subboroughdf)

# %%
plt.hist(Manhattan['Income'], bins = 'auto');
plt.xlim(0, 400000)
# Out:
# (0, 400000)

# %%
plt.hist(Manhattan['Income'], bins = 'auto');
plt.xlim(800000, 1200000)
plt.ylim(0,100)
# Out:
# (0, 100)

# %%
SubMan1 = Manhattan.groupby(['Sub-Borough']).get_group(1)

# %%
SubMan2 = Manhattan.groupby(['Sub-Borough']).get_group(2)

# %%
SubMan3 = Manhattan.groupby(['Sub-Borough']).get_group(3)

# %%
SubMan4 = Manhattan.groupby(['Sub-Borough']).get_group(4)

# %%
SubMan5 = Manhattan.groupby(['Sub-Borough']).get_group(5)

# %%
SubMan6 = Manhattan.groupby(['Sub-Borough']).get_group(6)

# %%
SubMan7 = Manhattan.groupby(['Sub-Borough']).get_group(7)

# %%
SubMan8 = Manhattan.groupby(['Sub-Borough']).get_group(8)

# %%
SubMan9 = Manhattan.groupby(['Sub-Borough']).get_group(9)

# %%
SubMan10 = Manhattan.groupby(['Sub-Borough']).get_group(10)

# %%
SubMan1.describe()
# Out:
#           Age  Borough    Income     Sex  Sub-Borough
# count  560.00    560.0  5.60e+02  560.00        560.0
# mean    42.80      3.0  1.42e+05    1.53          1.0
# std     17.28      0.0  2.03e+05    0.50          0.0
# min     15.00      3.0 -2.46e+04    1.00          1.0
# 25%     29.00      3.0  4.00e+04    1.00          1.0
# 50%     37.00      3.0  8.00e+04    2.00          1.0
# 75%     55.00      3.0  1.51e+05    2.00          1.0
# max     85.00      3.0  1.75e+06    2.00          1.0

# %%
SubMan2.describe()
# Out:
#           Age  Borough     Income    Sex  Sub-Borough
# count  589.00    589.0     589.00  589.0        589.0
# mean    45.09      3.0   48598.13    1.5          2.0
# std     18.27      0.0   59920.77    0.5          0.0
# min     16.00      3.0   -4550.00    1.0          2.0
# 25%     29.00      3.0   12000.00    1.0          2.0
# 50%     41.00      3.0   32000.00    2.0          2.0
# 75%     60.00      3.0   66000.00    2.0          2.0
# max     85.00      3.0  911502.00    2.0          2.0

# %%
SubMan3.describe()
# Out:
#           Age  Borough    Income     Sex  Sub-Borough
# count  579.00    579.0  5.79e+02  579.00        579.0
# mean    44.66      3.0  1.00e+05    1.42          3.0
# std     16.74      0.0  1.41e+05    0.49          0.0
# min     16.00      3.0  7.10e+01    1.00          3.0
# 25%     30.00      3.0  2.87e+04    1.00          3.0
# 50%     42.00      3.0  6.80e+04    1.00          3.0
# 75%     57.00      3.0  1.10e+05    2.00          3.0
# max     85.00      3.0  1.18e+06    2.00          3.0

# %%
SubMan4.describe()
# Out:
#           Age  Borough     Income     Sex  Sub-Borough
# count  612.00    612.0     612.00  612.00        612.0
# mean    43.20      3.0  118385.28    1.54          4.0
# std     17.98      0.0  166019.47    0.50          0.0
# min     18.00      3.0     500.00    1.00          4.0
# 25%     28.00      3.0   40000.00    1.00          4.0
# 50%     37.00      3.0   70000.00    2.00          4.0
# 75%     56.00      3.0  125000.00    2.00          4.0
# max     85.00      3.0  929679.00    2.00          4.0

# %%
SubMan5.describe()
# Out:
#           Age  Borough    Income     Sex  Sub-Borough
# count  750.00    750.0  7.50e+02  750.00        750.0
# mean    49.54      3.0  1.44e+05    1.53          5.0
# std     17.82      0.0  2.14e+05    0.50          0.0
# min     15.00      3.0 -8.00e+04    1.00          5.0
# 25%     34.00      3.0  3.00e+04    1.00          5.0
# 50%     47.00      3.0  6.95e+04    2.00          5.0
# 75%     64.00      3.0  1.50e+05    2.00          5.0
# max     85.00      3.0  1.22e+06    2.00          5.0

# %%
SubMan6.describe()
# Out:
#           Age  Borough    Income     Sex  Sub-Borough
# count  867.00    867.0  8.67e+02  867.00        867.0
# mean    48.41      3.0  1.35e+05    1.55          6.0
# std     18.40      0.0  2.23e+05    0.50          0.0
# min     15.00      3.0 -5.00e+03    1.00          6.0
# 25%     32.00      3.0  3.92e+04    1.00          6.0
# 50%     46.00      3.0  7.10e+04    2.00          6.0
# 75%     64.00      3.0  1.25e+05    2.00          6.0
# max     85.00      3.0  1.76e+06    2.00          6.0

# %%
SubMan7.describe()
# Out:
#           Age  Borough     Income     Sex  Sub-Borough
# count  541.00    541.0     541.00  541.00        541.0
# mean    46.75      3.0   37334.87    1.52          7.0
# std     18.52      0.0   57670.70    0.50          0.0
# min     15.00      3.0   -3750.00    1.00          7.0
# 25%     30.00      3.0   10000.00    1.00          7.0
# 50%     45.00      3.0   20400.00    2.00          7.0
# 75%     61.00      3.0   41000.00    2.00          7.0
# max     85.00      3.0  861502.00    2.00          7.0

# %%
SubMan8.describe()
# Out:
#           Age  Borough     Income     Sex  Sub-Borough
# count  606.00    606.0     606.00  606.00        606.0
# mean    45.44      3.0   41757.80    1.55          8.0
# std     16.82      0.0   63078.46    0.50          0.0
# min     15.00      3.0  -24550.00    1.00          8.0
# 25%     32.00      3.0   12000.00    1.00          8.0
# 50%     44.00      3.0   27850.00    2.00          8.0
# 75%     57.00      3.0   50000.00    2.00          8.0
# max     85.00      3.0  879679.00    2.00          8.0

# %%
SubMan9.describe()
# Out:
#           Age  Borough     Income     Sex  Sub-Borough
# count  368.00    368.0     368.00  368.00        368.0
# mean    48.08      3.0   36905.88    1.59          9.0
# std     17.52      0.0   72821.17    0.49          0.0
# min     15.00      3.0  -14914.00    1.00          9.0
# 25%     33.00      3.0   12090.00    1.00          9.0
# 50%     48.00      3.0   24000.00    2.00          9.0
# 75%     61.00      3.0   39125.00    2.00          9.0
# max     85.00      3.0  871502.00    2.00          9.0

# %%
SubMan10.describe()
# Out:
#           Age  Borough     Income     Sex  Sub-Borough
# count  824.00    824.0     824.00  824.00        824.0
# mean    46.98      3.0   33973.02    1.52         10.0
# std     18.04      0.0   47763.67    0.50          0.0
# min     15.00      3.0  -24550.00    1.00         10.0
# 25%     31.00      3.0    9803.00    1.00         10.0
# 50%     45.00      3.0   20000.00    2.00         10.0
# 75%     61.00      3.0   43143.75    2.00         10.0
# max     85.00      3.0  879679.00    2.00         10.0

# %%
plt.hist(SubMan1['Income'], bins = 'auto');
plt.xlim(0,1000000)
# Out:
# (0, 1000000)

# %%
plt.hist(SubMan2['Income'], bins = 'auto');
plt.xlim(0,150000)
# Out:
# (0, 150000)

# %%
plt.hist(SubMan3['Income'], bins = 'auto');
plt.xlim(0,400000)
# Out:
# (0, 400000)

# %%
plt.hist(SubMan4['Income'], bins = 'auto');
plt.xlim(0,400000)
# Out:
# (0, 400000)

# %%
plt.hist(SubMan5['Income'], bins = 'auto');
plt.xlim(0,400000)
# Out:
# (0, 400000)

# %%
plt.hist(SubMan6['Income'], bins = 'auto');
plt.xlim(0,400000)
# Out:
# (0, 400000)

# %%
plt.hist(SubMan7['Income'], bins = 'auto');
plt.xlim(0,250000)
# Out:
# (0, 250000)

# %%
plt.hist(SubMan8['Income'], bins = 'auto');
plt.xlim(0,200000)
# Out:
# (0, 200000)

# %%
plt.hist(SubMan9['Income'], bins = 'auto');
plt.xlim(0,100000)
# Out:
# (0, 100000)

# %%
plt.hist(SubMan10['Income'], bins = 'auto');
plt.xlim(0,200000)
# Out:
# (0, 200000)

# %%
SubBrook1 = Brooklyn.groupby(['Sub-Borough']).get_group(2)

# %%
plt.hist(SubBrook1['Income'], bins = 'auto');
plt.xlim(0,400000)
# Out:
# (0, 400000)
